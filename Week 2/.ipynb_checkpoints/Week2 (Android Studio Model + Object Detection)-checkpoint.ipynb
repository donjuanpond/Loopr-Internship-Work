# %% [markdown]
# # Overview
#
# __Mica Sheet Data__
# * https://drive.google.com/drive/folders/1ovVc82lUNM1h_o9XKa5YkpOlv-DeMFbj
# ***

# %% [markdown]
# # 6/24/2022
# * Created Mica Sheet Classification customvision.ai model
#
# # 6/26/2022
# * Was able to run https://github.com/tensorflow/examples/tree/master/lite/examples/image_classification/raspberry_pi image classification on raspberry pi
#
# # 6/27/2022
# * Created Mica Sheet Blister Detection customvision.ai model
# * Was able to run https://github.com/tensorflow/examples/tree/master/lite/examples/object_detection/android with example model on Android Emulator
# * Was able to run https://github.com/tensorflow/examples/tree/master/lite/examples/object_detection/raspberry_pi object detection on raspberry pi
#
# # 6/28/2022
# * Tried to run tflite model through raspberry pi with object detection as per [this tutorial](https://github.com/tensorflow/examples/tree/master/lite/examples/object_detection/raspberry_pi) but failed because of following error: <br>
# `RuntimeError: Input tensor has type kTfLiteFloat32: it requires specifying NormalizationOptions metadata to preprocess input images.` Essentially, I need to find out how to add metadata to the model, located at /home/pi/TensorFlowLite-Models/Blister-Detection/model.tflite on the raspberry pi.
# * https://stackoverflow.com/questions/67488032/how-to-apply-metadata-on-tflite-model could help: github page to run: https://github.com/tensorflow/examples/blob/master/lite/examples/image_classification/metadata/metadata_writer_for_image_classifier.py
#
# # 6/29/2022
# * By using code from [this](https://stackoverflow.com/questions/66727627/failed-to-initialize-detector-input-tensor-has-type-ktflitefloat32-ml-kit) problem (the code in the second answer), I was able to add metadata to the models. I was able to do this for classification and run a classification model on the raspberry pi through this method (got the tflite model from customvision export -> put it through the metadata program below
# * Sadly, adding metadata to the object detection model wasn't enough, as the object detection model exported from customvision was of the incorrect format to be used by the tensorflow demo app - this means that object detection with this model using the tflite demo apps will not be possible.

# %%
#IMAGE CLASSIFICATION METADATA ADDER
#https://stackoverflow.com/questions/66727627/failed-to-initialize-detector-input-tensor-has-type-ktflitefloat32-ml-kit

from tflite_support.metadata_writers import image_classifier
from tflite_support.metadata_writers import writer_utils
from tflite_support import metadata
ImageClassificationWriter = image_classifier.MetadataWriter
_MODEL_PATH = r"Mica Sheet Classification Model/model.tflite"     #Path where untagged model is found
# Task Library expects label files that are in the same format as the one below.
_LABEL_FILE = r"Mica Sheet Classification Model/labels.txt"       #Path where labels file is found
_SAVE_TO_PATH = r"Model with metadata/new-class-model.tflite"     #Path to save the model
# Normalization parameters is required when reprocessing the image. It is
# optional if the image pixel values are in range of [0, 255] and the input
# tensor is quantized to uint8. See the introduction for normalization and
# quantization parameters below for more details.
# https://www.tensorflow.org/lite/convert/metadata#normalization_and_quantization_parameters)
_INPUT_NORM_MEAN = 127.5
_INPUT_NORM_STD = 127.5

# Create the metadata writer.
writer = ImageClassificationWriter.create_for_inference(
    writer_utils.load_file(_MODEL_PATH), [_INPUT_NORM_MEAN], [_INPUT_NORM_STD],
    [_LABEL_FILE])

# Verify the metadata generated by metadata writer.
print(writer.get_metadata_json())

# Populate the metadata into the model.
writer_utils.save_file(writer.populate(), _SAVE_TO_PATH)
# Out:
# {
#   "name": "ImageClassifier",
#   "description": "Identify the most prominent object in the image from a known set of categories.",
#   "subgraph_metadata": [
#     {
#       "input_tensor_metadata": [
#         {
#           "name": "image",
#           "description": "Input image to be classified.",
#           "content": {
#             "content_properties_type": "ImageProperties",
#             "content_properties": {
#               "color_space": "RGB"
#             }
#           },
#           "process_units": [
#             {
#               "options_type": "NormalizationOptions",
#               "options": {
#                 "mean": [
#                   127.5
#                 ],
#                 "std": [
#                   127.5
#                 ]
#               }
#             }
#           ],
#           "stats": {
#             "max": [
#               1.0
#             ],
#             "min": [
#               -1.0
#             ]
#           }
#         }
# ...

# %% [markdown]
# # 6/30/2022
# * Doing Detectron2 tutorial: https://colab.research.google.com/drive/16jcaJoc6bCFAQ96jDe2HwtXj7BMD_-m5#scrollTo=FsePPpwZSmqt, https://www.youtube.com/watch?v=eUSgtfK4ivk, https://github.com/facebookresearch/detectron2

# %% [markdown]
# _Notes below use all three above links (youtube video guides through the CoLab file and uses the github repo_
#
# Detectron2 is a software system that implmements object detection algorithms. It uses the PyTorch deep learning framework and it can do both bounding boxes and object masks (pixel-by-pixel).
#
# ### Detectron2 Model Running in https://colab.research.google.com/drive/1ba2HBllvFarT_hFe0rh-ixzOxQs7EIn1
# #### Dataset Prep
# * Before you even start creating a model, you have to prepare your dataset by loading it in and then registering the dataset with Detectron2. To do this, you have to create a function that returns the items in the dataset as a list of dictionaries, where each dictionary can have the following fields (these fields are the keys in the dictionary, with values being the corresponding info), __more info here: https://detectron2.readthedocs.io/en/latest/tutorials/datasets.html__:
# ![image.png](attachment:image.png)
#
# * Once you register the data by inputting it as well as the dataset function into a `DatasetCatalog.register()` function, you have to add metadata for the datasets (metadata is basically info about the whole dataset such as the number of classes). To do this, you can run some code along the lines of `MetadataCatalog.get(dataset_name).some_key = some_value`<br><br>
#
# #### Model Creation
# * To create a Detectron2 model, you have to create a Detectron2 configuration (config or cfg). A model configuration file is an interface between the model and the program - it is a look-up table which tells the program what the parts of the model are, such as the weights of the model. You can also define values inside of it, such as the threshold needed for the model to draw a bounding box.<br><br>
#
# * Next, you train your model based off the dataset you prepared earlier. To do this, you have to run a number of different functions and create a trainer using the configuration file and then train the data.<br><br>
#
# * Next, you have to create a predictor using the config file, which has been updated with the trained model from the training process. This predictor will be used to generate an output prediction from an input image.<br><br>
#
# * These outputs (which are dictionaries) can then be parsed and visualized using Detectron2's built-in visualizer utilities and the cv2 library.<br><br>
#
# * You can then evaluate model performance using the COCO API and the AP metric implemented therein.<br><br>
#
# And just like that, you have created a model with Detectron2!!

# %% [markdown]
# # NOT WORKING ZONE

# %%
"""Writes metadata and label file to the image classifier models."""

from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import os

from absl import app
from absl import flags
import tensorflow as tf

import flatbuffers
# pylint: disable=g-direct-tensorflow-import
from tflite_support import metadata_schema_py_generated as _metadata_fb
from tflite_support import metadata as _metadata
# pylint: enable=g-direct-tensorflow-import

FLAGS = flags.FLAGS

#
#ADDED MODEL FILE PATH, LABEL FILE PATH, AND DESTINATION FILE PATH -AADI
#

def define_flags():
    flags.DEFINE_string("model_file", r"Mica Sheet Classification Model\model.tflite",
                      "Path and file name to the TFLite model file.")
    flags.DEFINE_string("label_file", r"Mica Sheet Classification Model\labels.txt", "Path to the label file.")
    flags.DEFINE_string("export_directory", r"C:\Users\aadia\OneDrive\Python\Loopr Work\Model with metadata",
                      "Path to save the TFLite model files with metadata.")
    flags.mark_flag_as_required("model_file")
    flags.mark_flag_as_required("label_file")
    flags.mark_flag_as_required("export_directory")


class ModelSpecificInfo(object):
    """Holds information that is specificly tied to an image classifier."""

    def __init__(self, name, version, image_width, image_height, image_min,
               image_max, mean, std, num_classes, author):
        self.name = name
        self.version = version
        self.image_width = image_width
        self.image_height = image_height
        self.image_min = image_min
        self.image_max = image_max
        self.mean = mean
        self.std = std
        self.num_classes = num_classes
        self.author = author


_MODEL_INFO = {
    "model.tflite":
        ModelSpecificInfo(
            name="model",
            version="v1",
            image_width=160,
            image_height=160,
            image_min=0,
            image_max=255,
            mean=[127.5],
            std=[127.5],
            num_classes=1001,
            author="TensorFlow")
}


class MetadataPopulatorForImageClassifier(object):
    """Populates the metadata for an image classifier."""

    def __init__(self, model_file, model_info, label_file_path):
        self.model_file = model_file
        self.model_info = model_info
        self.label_file_path = label_file_path
        self.metadata_buf = None

    def populate(self):
        """Creates metadata and then populates it for an image classifier."""
        self._create_metadata()
        self._populate_metadata()

    def _create_metadata(self):
        """Creates the metadata for an image classifier."""

        # Creates model info.
        model_meta = _metadata_fb.ModelMetadataT()
        model_meta.name = self.model_info.name
        model_meta.description = ("Identify the most prominent object in the "
                                  "image from a set of %d categories." %
                                  self.model_info.num_classes)
        model_meta.version = self.model_info.version
        model_meta.author = self.model_info.author
        model_meta.license = ("Apache License. Version 2.0 "
                              "http://www.apache.org/licenses/LICENSE-2.0.")

        # Creates input info.
        input_meta = _metadata_fb.TensorMetadataT()
        input_meta.name = "image"
        input_meta.description = (
            "Input image to be classified. The expected image is {0} x {1}, with "
            "three channels (red, blue, and green) per pixel. Each value in the "
            "tensor is a single byte between {2} and {3}.".format(
                self.model_info.image_width, self.model_info.image_height,
                self.model_info.image_min, self.model_info.image_max))
        input_meta.content = _metadata_fb.ContentT()
        input_meta.content.contentProperties = _metadata_fb.ImagePropertiesT()
        input_meta.content.contentProperties.colorSpace = (
            _metadata_fb.ColorSpaceType.RGB)
        input_meta.content.contentPropertiesType = (
            _metadata_fb.ContentProperties.ImageProperties)
        input_normalization = _metadata_fb.ProcessUnitT()
        input_normalization.optionsType = (
            _metadata_fb.ProcessUnitOptions.NormalizationOptions)
        input_normalization.options = _metadata_fb.NormalizationOptionsT()
        input_normalization.options.mean = self.model_info.mean
        input_normalization.options.std = self.model_info.std
        input_meta.processUnits = [input_normalization]
        input_stats = _metadata_fb.StatsT()
        input_stats.max = [self.model_info.image_max]
        input_stats.min = [self.model_info.image_min]
        input_meta.stats = input_stats

        # Creates output info.
        output_meta = _metadata_fb.TensorMetadataT()
        output_meta.name = "probability"
        output_meta.description = "Probabilities of the %d labels respectively." % self.model_info.num_classes
        output_meta.content = _metadata_fb.ContentT()
        output_meta.content.content_properties = _metadata_fb.FeaturePropertiesT()
        output_meta.content.contentPropertiesType = (
            _metadata_fb.ContentProperties.FeatureProperties)
        output_stats = _metadata_fb.StatsT()
        output_stats.max = [1.0]
        output_stats.min = [0.0]
        output_meta.stats = output_stats
        label_file = _metadata_fb.AssociatedFileT()
        label_file.name = os.path.basename(self.label_file_path)
        label_file.description = "Labels for objects that the model can recognize."
        label_file.type = _metadata_fb.AssociatedFileType.TENSOR_AXIS_LABELS
        output_meta.associatedFiles = [label_file]

        
        # Creates subgraph info.
        subgraph = _metadata_fb.SubGraphMetadataT()
        subgraph.inputTensorMetadata = [input_meta]
        subgraph.outputTensorMetadata = [output_meta]
        model_meta.subgraphMetadata = [subgraph]

        b = flatbuffers.Builder(0)
        b.Finish(
            model_meta.Pack(b),
            _metadata.MetadataPopulator.METADATA_FILE_IDENTIFIER)
        self.metadata_buf = b.Output()

    def _populate_metadata(self):
        """Populates metadata and label file to the model file."""
        populator = _metadata.MetadataPopulator.with_model_file(self.model_file)
        populator.load_metadata_buffer(self.metadata_buf)
        populator.load_associated_files([self.label_file_path])
        populator.populate()


def main(_):
    model_file = FLAGS.model_file
    model_basename = os.path.basename(model_file)
    if model_basename not in _MODEL_INFO:
        raise ValueError(
        "The model info for, {0}, is not defined yet.".format(model_basename))

    export_model_path = os.path.join(FLAGS.export_directory, model_basename)

  # Copies model_file to export_path.
    tf.io.gfile.copy(model_file, export_model_path, overwrite=False)

  # Generate the metadata objects and put them in the model file
    populator = MetadataPopulatorForImageClassifier(
        export_model_path, _MODEL_INFO.get(model_basename), FLAGS.label_file)
    populator.populate()

  # Validate the output model file by reading the metadata and produce
  # a json file with the metadata under the export path
    displayer = _metadata.MetadataDisplayer.with_model_file(export_model_path)
    export_json_file = os.path.join(FLAGS.export_directory,
                                  os.path.splitext(model_basename)[0] + ".json")
    json_file = displayer.get_metadata_json()
    with open(export_json_file, "w") as f:
        f.write(json_file)

    print("Finished populating metadata and associated file to the model:")
    print(model_file)
    print("The metadata json file has been saved to:")
    print(export_json_file)
    print("The associated file that has been been packed to the model is:")
    print(displayer.get_packed_associated_file_list())

# %%
#ADDED THIS CELL BECAUSE OF ERROR DURING RUNTIME IN BELOW CELL. FIXES THE ERROR.
#https://github.com/googlecolab/colabtools/issues/1323?adlt=strict&toWww=1&redig=4892989BD19A42ADADA94E99E33114CE

import sys

# Addresses `UnrecognizedFlagError: Unknown command line flag 'f'`
sys.argv = sys.argv[:1]

# `app.run` calls `sys.exit`
try:
    app.run(lambda argv: None)
except:
    pass

# %%
#Do this to run the program and add the TFLite model with metadata to a specified file path.
app.run(main)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-60-8408dd85c91b> in <module>
#       1 #Do this to run the program and add the TFLite model with metadata to a specified file path.
# ----> 2 app.run(main)
#
# C:\ProgramData\Anaconda3\lib\site-packages\absl\app.py in run(main, argv, flags_parser)
#     310       callback()
#     311     try:
# --> 312       _run_main(main, args)
#     313     except UsageError as error:
#     314       usage(shorthelp=True, detailed_error=error, exitcode=error.exitcode)
#
# C:\ProgramData\Anaconda3\lib\site-packages\absl\app.py in _run_main(main, argv)
#     256     sys.exit(retval)
#     257   else:
# --> 258     sys.exit(main(argv))
#     259
#     260
#
# <ipython-input-57-1ac659b71848> in main(_)
#     172     populator = MetadataPopulatorForImageClassifier(
# ...
